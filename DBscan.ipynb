# %%
# %matplotlib inline
import pandas as pd
import seaborn as sns
from matplotlib import pyplot as plt
import numpy as np

# %%
df = pd.read_csv(r"telemetry.csv")

# %%
df_9 = df.loc[df['machineID']==79]
df_9
# Out:
#                     datetime  machineID        volt      rotate    pressure  \
# 683358   1/1/2015 6:00:00 AM         79  194.167651  535.302327   84.071434
# 683359   1/1/2015 7:00:00 AM         79  180.989438  429.031142   96.245928
# 683360   1/1/2015 8:00:00 AM         79  208.452257  374.095525  106.340279
# 683361   1/1/2015 9:00:00 AM         79  192.161379  438.784836   94.309427
# 683362  1/1/2015 10:00:00 AM         79  207.822427  391.115326  103.079753
# ...                      ...        ...         ...         ...         ...
# 692114   1/1/2016 2:00:00 AM         79  177.910522  433.976274  107.094084
# 692115   1/1/2016 3:00:00 AM         79  180.127797  436.211213  104.491802
# 692116   1/1/2016 4:00:00 AM         79  169.745637  372.878963   97.541576
# 692117   1/1/2016 5:00:00 AM         79  159.103198  377.872351  110.863162
# 692118   1/1/2016 6:00:00 AM         79  170.478830  332.496519   98.481994
#
#         vibration
# 683358  35.654640
# 683359  37.163490
# 683360  37.617635
# 683361  47.383279
# 683362  39.579032
# ...           ...
# 692114  37.899328
# 692115  40.133926
# 692116  42.876531
# 692117  43.935968
# 692118  37.235609
#
# [8761 rows x 6 columns]

# %%
error = pd.read_csv(r"errors.csv")

# %%
error_9 = error.loc[error['machineID']==28]

# %%
error_9
# Out:
#                     datetime  machineID errorID
# 1062    1/11/2015 6:00:00 AM         28  error4
# 1063   1/25/2015 10:00:00 PM         28  error4
# 1064    1/26/2015 2:00:00 PM         28  error1
# 1065    1/27/2015 4:00:00 PM         28  error3
# 1066     2/1/2015 4:00:00 PM         28  error1
# 1067     3/6/2015 2:00:00 AM         28  error2
# 1068     3/9/2015 5:00:00 AM         28  error4
# 1069    3/16/2015 6:00:00 AM         28  error2
# 1070    3/16/2015 6:00:00 AM         28  error3
# 1071   3/16/2015 12:00:00 PM         28  error2
# 1072    3/30/2015 7:00:00 AM         28  error4
# 1073    3/31/2015 7:00:00 AM         28  error2
# 1074    4/12/2015 1:00:00 AM         28  error1
# 1075    4/14/2015 2:00:00 AM         28  error1
# 1076    4/30/2015 6:00:00 AM         28  error1
# 1077   5/10/2015 11:00:00 PM         28  error1
# 1078    5/24/2015 6:00:00 PM         28  error5
# 1079     6/4/2015 2:00:00 PM         28  error3
# 1080     6/9/2015 8:00:00 PM         28  error2
# 1081    6/12/2015 4:00:00 PM         28  error3
# 1082    6/14/2015 6:00:00 AM         28  error2
# 1083    6/14/2015 6:00:00 AM         28  error3
# 1084    6/18/2015 5:00:00 AM         28  error3
# 1085    7/8/2015 11:00:00 PM         28  error4
# 1086    7/13/2015 8:00:00 PM         28  error2
# 1087    7/30/2015 4:00:00 AM         28  error2
# 1088    8/2/2015 12:00:00 AM         28  error1
# 1089     8/3/2015 3:00:00 AM         28  error2
# 1090    8/13/2015 6:00:00 AM         28  error1
# 1091    8/24/2015 6:00:00 AM         28  error3
# 1092    9/7/2015 10:00:00 PM         28  error2
# 1093    9/9/2015 11:00:00 AM         28  error2
# 1094   9/28/2015 11:00:00 PM         28  error5
# 1095   10/19/2015 9:00:00 AM         28  error1
# 1096  11/13/2015 12:00:00 PM         28  error2
# 1097  11/26/2015 11:00:00 PM         28  error1
# 1098   12/17/2015 2:00:00 PM         28  error3
# 1099   12/24/2015 9:00:00 AM         28  error1
# 1100   12/26/2015 6:00:00 AM         28  error1
# 1101   12/27/2015 4:00:00 PM         28  error1

# %%
merged_9 = df_9.merge(error_9,how='outer', left_on='datetime',right_on='datetime')

# %%
merged_9.head(120)
# Out:
#                  datetime  machineID_x        volt      rotate    pressure  \
# 0     1/1/2015 6:00:00 AM           79  194.167651  535.302327   84.071434
# 1     1/1/2015 7:00:00 AM           79  180.989438  429.031142   96.245928
# 2     1/1/2015 8:00:00 AM           79  208.452257  374.095525  106.340279
# 3     1/1/2015 9:00:00 AM           79  192.161379  438.784836   94.309427
# 4    1/1/2015 10:00:00 AM           79  207.822427  391.115326  103.079753
# ..                    ...          ...         ...         ...         ...
# 115   1/6/2015 1:00:00 AM           79  162.217285  420.230333   86.936240
# 116   1/6/2015 2:00:00 AM           79  173.620936  441.424657  106.288635
# 117   1/6/2015 3:00:00 AM           79  155.233733  401.571424  103.123505
# 118   1/6/2015 4:00:00 AM           79  177.127633  467.620414   98.270977
# 119   1/6/2015 5:00:00 AM           79  156.526779  390.471823  118.707003
#
#      vibration  machineID_y errorID
# 0    35.654640          NaN     NaN
# 1    37.163490          NaN     NaN
# 2    37.617635          NaN     NaN
# 3    47.383279          NaN     NaN
# 4    39.579032          NaN     NaN
# ..         ...          ...     ...
# 115  44.633433          NaN     NaN
# 116  35.766281          NaN     NaN
# 117  39.631507          NaN     NaN
# 118  50.214198          NaN     NaN
# 119  40.262577          NaN     NaN
#
# [120 rows x 8 columns]

# %%
merged_9['errorID'].fillna("None",inplace=True)

# %%
merged_9
# Out:
#                   datetime  machineID_x        volt      rotate    pressure  \
# 0      1/1/2015 6:00:00 AM           79  194.167651  535.302327   84.071434
# 1      1/1/2015 7:00:00 AM           79  180.989438  429.031142   96.245928
# 2      1/1/2015 8:00:00 AM           79  208.452257  374.095525  106.340279
# 3      1/1/2015 9:00:00 AM           79  192.161379  438.784836   94.309427
# 4     1/1/2015 10:00:00 AM           79  207.822427  391.115326  103.079753
# ...                    ...          ...         ...         ...         ...
# 8758   1/1/2016 2:00:00 AM           79  177.910522  433.976274  107.094084
# 8759   1/1/2016 3:00:00 AM           79  180.127797  436.211213  104.491802
# 8760   1/1/2016 4:00:00 AM           79  169.745637  372.878963   97.541576
# 8761   1/1/2016 5:00:00 AM           79  159.103198  377.872351  110.863162
# 8762   1/1/2016 6:00:00 AM           79  170.478830  332.496519   98.481994
#
#       vibration  machineID_y errorID
# 0     35.654640          NaN    None
# 1     37.163490          NaN    None
# 2     37.617635          NaN    None
# 3     47.383279          NaN    None
# 4     39.579032          NaN    None
# ...         ...          ...     ...
# 8758  37.899328          NaN    None
# 8759  40.133926          NaN    None
# 8760  42.876531          NaN    None
# 8761  43.935968          NaN    None
# 8762  37.235609          NaN    None
#
# [8763 rows x 8 columns]

# %%
merged_9.drop('machineID_y',axis=1,inplace=True)
merged_9
# Out:
#                   datetime  machineID_x        volt      rotate    pressure  \
# 0      1/1/2015 6:00:00 AM           79  194.167651  535.302327   84.071434
# 1      1/1/2015 7:00:00 AM           79  180.989438  429.031142   96.245928
# 2      1/1/2015 8:00:00 AM           79  208.452257  374.095525  106.340279
# 3      1/1/2015 9:00:00 AM           79  192.161379  438.784836   94.309427
# 4     1/1/2015 10:00:00 AM           79  207.822427  391.115326  103.079753
# ...                    ...          ...         ...         ...         ...
# 8758   1/1/2016 2:00:00 AM           79  177.910522  433.976274  107.094084
# 8759   1/1/2016 3:00:00 AM           79  180.127797  436.211213  104.491802
# 8760   1/1/2016 4:00:00 AM           79  169.745637  372.878963   97.541576
# 8761   1/1/2016 5:00:00 AM           79  159.103198  377.872351  110.863162
# 8762   1/1/2016 6:00:00 AM           79  170.478830  332.496519   98.481994
#
#       vibration errorID
# 0     35.654640    None
# 1     37.163490    None
# 2     37.617635    None
# 3     47.383279    None
# 4     39.579032    None
# ...         ...     ...
# 8758  37.899328    None
# 8759  40.133926    None
# 8760  42.876531    None
# 8761  43.935968    None
# 8762  37.235609    None
#
# [8763 rows x 7 columns]

# %%
merged_9.replace(to_replace=['None','error1','error2','error3','error4','error5'],value=[0,1,2,3,4,5],inplace=True)

# %%
merged_9
# Out:
#                   datetime  machineID_x        volt      rotate    pressure  \
# 0      1/1/2015 6:00:00 AM           79  194.167651  535.302327   84.071434
# 1      1/1/2015 7:00:00 AM           79  180.989438  429.031142   96.245928
# 2      1/1/2015 8:00:00 AM           79  208.452257  374.095525  106.340279
# 3      1/1/2015 9:00:00 AM           79  192.161379  438.784836   94.309427
# 4     1/1/2015 10:00:00 AM           79  207.822427  391.115326  103.079753
# ...                    ...          ...         ...         ...         ...
# 8758   1/1/2016 2:00:00 AM           79  177.910522  433.976274  107.094084
# 8759   1/1/2016 3:00:00 AM           79  180.127797  436.211213  104.491802
# 8760   1/1/2016 4:00:00 AM           79  169.745637  372.878963   97.541576
# 8761   1/1/2016 5:00:00 AM           79  159.103198  377.872351  110.863162
# 8762   1/1/2016 6:00:00 AM           79  170.478830  332.496519   98.481994
#
#       vibration  errorID
# 0     35.654640        0
# 1     37.163490        0
# 2     37.617635        0
# 3     47.383279        0
# 4     39.579032        0
# ...         ...      ...
# 8758  37.899328        0
# 8759  40.133926        0
# 8760  42.876531        0
# 8761  43.935968        0
# 8762  37.235609        0
#
# [8763 rows x 7 columns]

# %%
from sklearn.cluster import DBSCAN
import sklearn.utils
from sklearn.preprocessing import StandardScaler
sklearn.utils.check_random_state(1000)
#Clus_dataSet = merged[['vibration','rotate','errorID','volt']]
Clus_dataSet = merged_9[['volt','rotate','vibration','errorID']]
#Clus_dataSet = np.nan_to_num(Clus_dataSet)
Clus_dataSet = StandardScaler().fit_transform(Clus_dataSet)

# Compute DBSCAN
db = DBSCAN(eps=3.54, min_samples=3).fit(Clus_dataSet)
core_samples_mask = np.zeros_like(db.labels_, dtype=bool)
core_samples_mask[db.core_sample_indices_] = True
labels = db.labels_
merged_9["Clus_Db"]=labels

realClusterNum=len(set(labels)) - (1 if -1 in labels else 0)
clusterNum = len(set(labels)) 


# A sample of clusters
merged_9[['volt','rotate','pressure','vibration','errorID','Clus_Db']].head(120)
# Out:
#            volt      rotate    pressure  vibration  errorID  Clus_Db
# 0    194.167651  535.302327   84.071434  35.654640        0        0
# 1    180.989438  429.031142   96.245928  37.163490        0        0
# 2    208.452257  374.095525  106.340279  37.617635        0        0
# 3    192.161379  438.784836   94.309427  47.383279        0        0
# 4    207.822427  391.115326  103.079753  39.579032        0        0
# ..          ...         ...         ...        ...      ...      ...
# 115  162.217285  420.230333   86.936240  44.633433        0        0
# 116  173.620936  441.424657  106.288635  35.766281        0        0
# 117  155.233733  401.571424  103.123505  39.631507        0        0
# 118  177.127633  467.620414   98.270977  50.214198        0        0
# 119  156.526779  390.471823  118.707003  40.262577        0        0
#
# [120 rows x 6 columns]

# %%
y_pred = db.fit_predict(Clus_dataSet)
y_pred
# Out:
# array([0, 0, 0, ..., 0, 0, 0], dtype=int64)

# %%
plt.scatter(Clus_dataSet[:,0], Clus_dataSet[:,1],c=y_pred,marker='x')
plt.title("DBSCAN")
# Out:
# Text(0.5, 1.0, 'DBSCAN')

# %%
merged_9.to_csv("merged-9.csv")
